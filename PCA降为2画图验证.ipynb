# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import itertools
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import auc, roc_curve
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
df_wine = pd.read_csv('D:\my_dateset\wine.csv')

# %%
le = LabelEncoder()
df_wine['type'] = le.fit_transform(df_wine['type'])
le.classes_
le.transform(le.classes_)
dict(zip(le.classes_, le.transform(le.classes_)))
df_wine.head(3)
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     0            7.4              0.70         0.00             1.9
# 1     0            7.8              0.88         0.00             2.6
# 2     0            7.8              0.76         0.04             2.3
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5

# %%
x=df_wine.drop(['type'],axis=1) # 数据去除lable列
sc=StandardScaler().fit(x) # 标准化处理，将特征中的值进行标准差标准化，形成正态分布 通过标准化处理，可以使得不同的特征变量具有相同的尺度
df_wine_sc=pd.DataFrame(sc.transform(x),columns=x.columns)  #形成数据标准化处理表格
df_wine_sc.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.142473          2.188833    -2.192833       -0.744778   0.569958
# 1       0.451036          3.282235    -2.192833       -0.597640   1.197975
# 2       0.451036          2.553300    -1.917553       -0.660699   1.026697
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -1.100140             -1.446359  1.034993  1.813090   0.193097
# 1            -0.311320             -0.862469  0.701486 -0.115073   0.999579
# 2            -0.874763             -1.092486  0.768188  0.258120   0.797958
#
#     alcohol  quality
# 0 -0.915464 -0.93723
# 1 -0.580068 -0.93723
# 2 -0.580068 -0.93723

# %%
pca1=PCA(n_components=2)
pc2=pca1.fit_transform(df_wine_sc)
pc3=pd.DataFrame(data=pc2,columns = ['comp1', 'comp2'])#转换为表格
df_wine_pc2=pd.concat([pc3,df_wine['type']],axis=1)
df_wine_pc2.head(10)
# Out:
#       comp1     comp2  type
# 0 -3.348438  0.568926     0
# 1 -3.228595  1.197335     0
# 2 -3.237468  0.952580     0
# 3 -1.672561  1.600583     0
# 4 -3.348438  0.568926     0
# 5 -3.152236  0.556274     0
# 6 -2.283060  0.538981     0
# 7 -2.564991 -1.104080     0
# 8 -2.867852 -0.231333     0
# 9 -1.816551  1.183721     0

# %%
X=pc3
Y=df_wine['type']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train.shape, X_test.shape
LR1 = LogisticRegression()
LR1.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
plot_decision_regions(X_train, Y_train, classifier=LR1, test_idx=range(105,150))
plt.figure(figsize=(5, 4),dpi=600)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(loc='lower left')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2267ab912c57> in <module>()
# ----> 1 plot_decision_regions(X_train, Y_train, classifier=LR1, test_idx=range(105,150))
#       2 plt.figure(figsize=(5, 4),dpi=600)
#       3 plt.xlabel('PC1')
#       4 plt.ylabel('PC2')
#       5 plt.legend(loc='lower left')
#
# NameError: name 'plot_decision_regions' is not defined
